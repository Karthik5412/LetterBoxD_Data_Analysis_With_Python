# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('netflix_movies_detailed_up_to_2025.csv')

# %%
df.head()
# Out:
#    show_id   type                                         title  \
# 0    10192  Movie                           Shrek Forever After
# 1    27205  Movie                                     Inception
# 2    12444  Movie  Harry Potter and the Deathly Hallows: Part 1
# 3    38757  Movie                                       Tangled
# 4    10191  Movie                      How to Train Your Dragon
#
#                       director  \
# 0                Mike Mitchell
# 1            Christopher Nolan
# 2                  David Yates
# 3   Byron Howard, Nathan Greno
# 4  Chris Sanders, Dean DeBlois
#
#                                                 cast  \
# 0  Mike Myers, Eddie Murphy, Cameron Diaz, Antoni...
# 1  Leonardo DiCaprio, Joseph Gordon-Levitt, Ken W...
# 2  Daniel Radcliffe, Emma Watson, Rupert Grint, T...
# 3  Mandy Moore, Zachary Levi, Donna Murphy, Ron P...
# 4  Jay Baruchel, Gerard Butler, Craig Ferguson, A...
#
#                                     country  date_added  release_year  rating  \
# 0                  United States of America  2010-05-16          2010   6.380
# 1  United Kingdom, United States of America  2010-07-15          2010   8.369
# 2  United Kingdom, United States of America  2010-11-17          2010   7.744
# 3                  United States of America  2010-11-24          2010   7.600
# 4                  United States of America  2010-03-18          2010   7.800
#
#    duration                                         genres language  \
# 0       NaN  Comedy, Adventure, Fantasy, Animation, Family       en
# 1       NaN             Action, Science Fiction, Adventure       en
# 2       NaN                             Adventure, Fantasy       en
# 3       NaN                   Animation, Family, Adventure       en
# 4       NaN          Fantasy, Adventure, Animation, Family       en
#
#                                          description  popularity  vote_count  \
# 0  A bored and domesticated Shrek pacts with deal...     203.893        7449
# 1  Cobb, a skilled thief who commits corporate es...     156.242       37119
# 2  Harry, Ron and Hermione walk away from their l...     121.191       19327
# 3  Feisty teenager Rapunzel, who has long and mag...     111.762       11638
# 4  As the son of a Viking leader on the cusp of m...     110.044       13259
#
#    vote_average     budget    revenue
# 0         6.380  165000000  752600867
# 1         8.369  160000000  839030630
# 2         7.744  250000000  954305868
# 3         7.600  260000000  592461732
# 4         7.800  165000000  494879471

# %% [markdown]
# ### EDA

# %%
df.shape
# Out:
# (16000, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16000 entries, 0 to 15999
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       16000 non-null  int64
#  1   type          16000 non-null  object
#  2   title         16000 non-null  object
#  3   director      15868 non-null  object
#  4   cast          15796 non-null  object
#  5   country       15534 non-null  object
#  6   date_added    16000 non-null  object
#  7   release_year  16000 non-null  int64
#  8   rating        16000 non-null  float64
#  9   duration      0 non-null      float64
#  10  genres        15893 non-null  object
#  11  language      16000 non-null  object
#  12  description   15868 non-null  object
#  13  popularity    16000 non-null  float64
#  14  vote_count    16000 non-null  int64
#  15  vote_average  16000 non-null  float64
#  16  budget        16000 non-null  int64
#  17  revenue       16000 non-null  int64
# dtypes: float64(4), int64(5), object(9)
# memory usage: 2.2+ MB

# %%
df.describe()
# Out:
#             show_id  release_year        rating  duration    popularity  \
# count  1.600000e+04  16000.000000  16000.000000       0.0  16000.000000
# mean   5.266582e+05   2017.500000      5.956368       NaN     20.384728
# std    3.794427e+05      4.609916      1.754741       NaN     68.610033
# min    1.890000e+02   2010.000000      0.000000       NaN      3.860000
# 25%    2.257258e+05   2013.750000      5.600000       NaN      7.840750
# 50%    4.468170e+05   2017.500000      6.300000       NaN     10.913500
# 75%    7.739808e+05   2021.250000      6.923000       NaN     17.336500
# max    1.440471e+06   2025.000000     10.000000       NaN   3876.006000
#
#          vote_count  vote_average        budget       revenue
# count  16000.000000  16000.000000  1.600000e+04  1.600000e+04
# mean     718.656125      5.956368  8.766792e+06  2.446308e+07
# std     2080.198316      1.754741  2.912450e+07  1.116977e+08
# min        0.000000      0.000000  0.000000e+00  0.000000e+00
# 25%       53.000000      5.600000  0.000000e+00  0.000000e+00
# 50%      138.000000      6.300000  0.000000e+00  0.000000e+00
# 75%      422.000000      6.923000  2.200000e+06  1.654473e+06
# max    37119.000000     10.000000  4.600000e+08  2.799439e+09

# %% [markdown]
# #### Droping Unwanted columns

# %%
# Listing Columns to remove
un_cols = ['type','release_year','duration']
df = df.drop(columns= un_cols)

# %% [markdown]
# ### Handling Null Values

# %%
df.isna().sum()
# Out:
# show_id           0
# title             0
# director        132
# cast            204
# country         466
# date_added        0
# rating            0
# genres          107
# language          0
# description     132
# popularity        0
# vote_count        0
# vote_average      0
# budget            0
# revenue           0
# dtype: int64

# %%
na_cols = ['director','cast','genres','description']
df = df.dropna(subset=na_cols)

df.isna().sum()
# Out:
# show_id           0
# title             0
# director          0
# cast              0
# country         319
# date_added        0
# rating            0
# genres            0
# language          0
# description       0
# popularity        0
# vote_count        0
# vote_average      0
# budget            0
# revenue           0
# dtype: int64

# %%
# Filling Country column with mode value
df['country'] = df['country'].fillna(df['country'].mode()[0])
df.isna().sum()
# Out:
# show_id         0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# rating          0
# genres          0
# language        0
# description     0
# popularity      0
# vote_count      0
# vote_average    0
# budget          0
# revenue         0
# dtype: int64

# %%
df['popularity'] = df['popularity'].replace(0,df['popularity'].mean())
df['vote_count'] = df['vote_count'].replace(0,df['vote_count'].mean())
df['budget'] = df['budget'].replace(0,df['budget'].mean())
df['vote_average'] = df['vote_average'].replace(0,df['vote_average'].mean())
df['revenue'] = df['revenue'].replace(0,df['revenue'].mean())
df['rating'] = df['rating'].replace(0,df['rating'].mean())

# %%
df.head(2)
# Out:
#    show_id                title           director  \
# 0    10192  Shrek Forever After      Mike Mitchell
# 1    27205            Inception  Christopher Nolan
#
#                                                 cast  \
# 0  Mike Myers, Eddie Murphy, Cameron Diaz, Antoni...
# 1  Leonardo DiCaprio, Joseph Gordon-Levitt, Ken W...
#
#                                     country  date_added  rating  \
# 0                  United States of America  2010-05-16   6.380
# 1  United Kingdom, United States of America  2010-07-15   8.369
#
#                                           genres language  \
# 0  Comedy, Adventure, Fantasy, Animation, Family       en
# 1             Action, Science Fiction, Adventure       en
#
#                                          description  popularity  vote_count  \
# 0  A bored and domesticated Shrek pacts with deal...     203.893      7449.0
# 1  Cobb, a skilled thief who commits corporate es...     156.242     37119.0
#
#    vote_average       budget      revenue
# 0         6.380  165000000.0  752600867.0
# 1         8.369  160000000.0  839030630.0

# %%
def clean(x):
    data = x.split(',')
    in_data = []
    for i in data:
        i = i.strip()
        in_data.append(i)
    return (',').join(in_data)

# %%
df['cast'] = df['cast'].apply(clean)
df['genres'] = df['genres'].apply(clean)
df['director'] = df['director'].apply(lambda x : x.strip())

# %%
df['date_added'] = pd.to_datetime(df['date_added'])
df['year'] = df['date_added'].dt.year
df['month'] = df['date_added'].dt.month
df['day'] = df['date_added'].dt.day
df['date_added']= pd.to_datetime(df['date_added'])
df.head()
# Out:
#    show_id                                         title  \
# 0    10192                           Shrek Forever After
# 1    27205                                     Inception
# 2    12444  Harry Potter and the Deathly Hallows: Part 1
# 3    38757                                       Tangled
# 4    10191                      How to Train Your Dragon
#
#                       director  \
# 0                Mike Mitchell
# 1            Christopher Nolan
# 2                  David Yates
# 3   Byron Howard, Nathan Greno
# 4  Chris Sanders, Dean DeBlois
#
#                                                 cast  \
# 0  Mike Myers,Eddie Murphy,Cameron Diaz,Antonio B...
# 1  Leonardo DiCaprio,Joseph Gordon-Levitt,Ken Wat...
# 2  Daniel Radcliffe,Emma Watson,Rupert Grint,Toby...
# 3  Mandy Moore,Zachary Levi,Donna Murphy,Ron Perl...
# 4  Jay Baruchel,Gerard Butler,Craig Ferguson,Amer...
#
#                                     country date_added  rating  \
# 0                  United States of America 2010-05-16   6.380
# 1  United Kingdom, United States of America 2010-07-15   8.369
# 2  United Kingdom, United States of America 2010-11-17   7.744
# 3                  United States of America 2010-11-24   7.600
# 4                  United States of America 2010-03-18   7.800
#
#                                       genres language  \
# 0  Comedy,Adventure,Fantasy,Animation,Family       en
# 1           Action,Science Fiction,Adventure       en
# 2                          Adventure,Fantasy       en
# 3                 Animation,Family,Adventure       en
# 4         Fantasy,Adventure,Animation,Family       en
#
#                                          description  popularity  vote_count  \
# 0  A bored and domesticated Shrek pacts with deal...     203.893      7449.0
# 1  Cobb, a skilled thief who commits corporate es...     156.242     37119.0
# 2  Harry, Ron and Hermione walk away from their l...     121.191     19327.0
# 3  Feisty teenager Rapunzel, who has long and mag...     111.762     11638.0
# 4  As the son of a Viking leader on the cusp of m...     110.044     13259.0
#
#    vote_average       budget      revenue  year  month  day
# 0         6.380  165000000.0  752600867.0  2010      5   16
# 1         8.369  160000000.0  839030630.0  2010      7   15
# 2         7.744  250000000.0  954305868.0  2010     11   17
# 3         7.600  260000000.0  592461732.0  2010     11   24
# 4         7.800  165000000.0  494879471.0  2010      3   18

# %%
df.to_csv('cleaned.csv')

# %%
countries_list = []
def clean(countries) :
    coun_list = countries.split(',')
    for country in coun_list :
        country = country.strip()
        if country not in countries_list:
            countries_list.append(country)

# %%
df['country'].apply(clean)
len(countries_list)
# Out:
# 133

# %%
unique_actors = []    
def actors(actors) :
    actors_list = actors.split(',')
    for actor in actors_list :
        actor = actor.strip()
        if actor not in unique_actors:
            unique_actors.append(actor)

# %%
df['cast'].apply(actors)
len(unique_actors)
# Out:
# 34704

# %%
unique_gener = []    
def geners_list(gener) :
    gener_list = gener.split(',')
    for gener in gener_list :
        gener = gener.strip()
        if gener not in unique_gener:
            unique_gener.append(gener)

# %%
df['genres'].apply(geners_list)
len(unique_gener)
# Out:
# 19

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15558 entries, 0 to 15999
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       15558 non-null  int64
#  1   title         15558 non-null  object
#  2   director      15558 non-null  object
#  3   cast          15558 non-null  object
#  4   country       15558 non-null  object
#  5   date_added    15558 non-null  datetime64[ns]
#  6   rating        15558 non-null  float64
#  7   genres        15558 non-null  object
#  8   language      15558 non-null  object
#  9   description   15558 non-null  object
#  10  popularity    15558 non-null  float64
#  11  vote_count    15558 non-null  float64
#  12  vote_average  15558 non-null  float64
#  13  budget        15558 non-null  float64
#  14  revenue       15558 non-null  float64
#  15  year          15558 non-null  int32
#  16  month         15558 non-null  int32
#  17  day           15558 non-null  int32
# dtypes: datetime64[ns](1), float64(6), int32(3), int64(1), object(7)
# memory usage: 2.1+ MB

# %%
def collapse(x):
    data = x.split(',')
    result = []
    for i in data :
        result.append(i.strip())
    return result
        

df_geners = df.copy()
df_geners['genres'] = df_geners['genres'].apply(collapse)
df_geners_expanded = df_geners.explode('genres').reset_index(drop=True)

df_countries = df.copy()
df_countries['country'] = df_countries['country'].apply(collapse)
df_countries_expanded = df_countries.explode('country').reset_index(drop=True)
df_countries_expanded.head(2)
# Out:
#    show_id                title           director  \
# 0    10192  Shrek Forever After      Mike Mitchell
# 1    27205            Inception  Christopher Nolan
#
#                                                 cast  \
# 0  Mike Myers,Eddie Murphy,Cameron Diaz,Antonio B...
# 1  Leonardo DiCaprio,Joseph Gordon-Levitt,Ken Wat...
#
#                     country date_added  rating  \
# 0  United States of America 2010-05-16   6.380
# 1            United Kingdom 2010-07-15   8.369
#
#                                       genres language  \
# 0  Comedy,Adventure,Fantasy,Animation,Family       en
# 1           Action,Science Fiction,Adventure       en
#
#                                          description  popularity  vote_count  \
# 0  A bored and domesticated Shrek pacts with deal...     203.893      7449.0
# 1  Cobb, a skilled thief who commits corporate es...     156.242     37119.0
#
#    vote_average       budget      revenue  year  month  day
# 0         6.380  165000000.0  752600867.0  2010      5   16
# 1         8.369  160000000.0  839030630.0  2010      7   15

# %%
import joblib
joblib.dump(unique_actors,'unique_actors.plk')
joblib.dump(df_geners_expanded,'gener_df.plk')
joblib.dump(df_countries_expanded,'country_df.plk')
# Out:
# ['country_df.plk']

# %%
df.sort_values(by='date_added',ascending=False)
# Out:
#        show_id                                              title  \
# 15366  1234731                                           Anaconda
# 15959  1317288                                      Marty Supreme
# 15641  1368166                                      The Housemaid
# 15865   511243  The Wizard Hunter: The Hunt for Evangelion Cro...
# 15078    83533                               Avatar: Fire and Ash
# ...        ...                                                ...
# 874      38883                                  Protect and Serve
# 613     333926                                       Online Crush
# 848      73101                                 The Killing Strain
# 443     113727                                     Dark Seduction
# 958      43615                            Lula, the Son of Brazil
#
#                               director  \
# 15366                     Tom Gormican
# 15959                      Josh Safdie
# 15641                        Paul Feig
# 15865                     Nico Toffoli
# 15078                    James Cameron
# ...                                ...
# 874                       Eric Lavaine
# 613                        Matt Taylor
# 848                   Daniel Maldonado
# 443                     Walter Doehner
# 958    Fábio Barreto, Marcelo Santiago
#
#                                                     cast  \
# 15366  Jack Black,Paul Rudd,Daniela Melchior,Thandiwe...
# 15959  Timothée Chalamet,Gwyneth Paltrow,Tyler,The Cr...
# 15641  Sydney Sweeney,Amanda Seyfried,Brandon Sklenar...
# 15865  Max Brown,Peter Stormare,Christopher Lambert,N...
# 15078  Sam Worthington,Zoe Saldaña,Sigourney Weaver,S...
# ...                                                  ...
# 874    Kad Merad,Clovis Cornillac,Carole Bouquet,Fran...
# 613    Evie Delatosso,Tiffany Tyler,Aubrey Addams,Ken...
# 848    Nina Leon,Venda D'Abato,Tom Lagleder,Brenda St...
# 443    Elizabeth Cervantes,Julio Bekhor,Marco Antonio...
# 958    Rui Ricardo Diaz,Glória Pires,Cleo,Juliana Bar...
#
#                                  country date_added    rating  \
# 15366           United States of America 2025-12-25  6.046694
# 15959  Finland, United States of America 2025-12-25  6.046694
# 15641           United States of America 2025-12-25  6.046694
# 15865           United States of America 2025-12-18  6.046694
# 15078           United States of America 2025-12-17  6.046694
# ...                                  ...        ...       ...
# 874                               France 2010-01-03  4.500000
# 613             United States of America 2010-01-01  4.800000
# 848             United States of America 2010-01-01  3.200000
# 443                               Mexico 2010-01-01  6.974000
# 958                               Brazil 2010-01-01  5.500000
#
#                                   genres language  \
# 15366            Horror,Adventure,Comedy       en
# 15959                              Drama       en
# 15641                   Thriller,Mystery       en
# 15865               Drama,Fantasy,Horror       en
# 15078  Science Fiction,Adventure,Fantasy       en
# ...                                  ...      ...
# 874                  Comedy,Crime,Action       fr
# 613                                Drama       en
# 848                      Horror,Thriller       fr
# 443               Drama,Thriller,Romance       es
# 958                        Drama,History       pt
#
#                                              description  popularity  \
# 15366                                    Planned reboot.      10.491
# 15959  A fictional story set in the world of 1950s pi...       5.096
# 15641  Millie is a struggling woman who is relieved t...       7.175
# 15865  A bounty hunter of lost masterpieces of any er...       5.704
# 15078  In the wake of the devastating war against the...      51.760
# ...                                                  ...         ...
# 874    A pair of bumbling French cops team up to take...       4.496
# 613    Love is just a mouse-click away for a single g...       6.330
# 848    A man-made virus, 'The Killing Strain'-- an ou...       4.599
# 443    Laura is a successful plastic surgeon who feel...       8.366
# 958    The true story of a working class boy who move...       4.045
#
#        vote_count  vote_average        budget       revenue  year  month  day
# 15366  738.221622      6.046694  9.013673e+06  2.515752e+07  2025     12   25
# 15959  738.221622      6.046694  7.000000e+07  2.515752e+07  2025     12   25
# 15641  738.221622      6.046694  9.013673e+06  2.515752e+07  2025     12   25
# 15865  738.221622      6.046694  9.013673e+06  2.515752e+07  2025     12   18
# 15078  738.221622      6.046694  4.000000e+08  2.515752e+07  2025     12   17
# ...           ...           ...           ...           ...   ...    ...  ...
# 874    101.000000      4.500000  9.013673e+06  3.807808e+06  2010      1    3
# 613      5.000000      4.800000  9.013673e+06  2.515752e+07  2010      1    1
# 848      5.000000      3.200000  9.013673e+06  2.515752e+07  2010      1    1
# 443     97.000000      6.974000  9.013673e+06  2.515752e+07  2010      1    1
# 958     80.000000      5.500000  9.500000e+06  3.785593e+06  2010      1    1
#
# [15558 rows x 18 columns]
